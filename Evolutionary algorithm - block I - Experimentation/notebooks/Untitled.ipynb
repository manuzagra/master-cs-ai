# %%
# !pip3 install -U notebook-as-pdf
# Out:
# ...
#      |████████████████████████████████| 145 kB 573 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 196 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 136 kB 91 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 69 kB 197 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 204 kB/s eta 0:00:01
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61084 sha256=6ef5012dd128cf23d720b34fa1fc79d884151d01d4ba0b033a087c37de8f7188
#   Stored in directory: /root/.cache/pip/wheels/b1/1a/8f/a4c34be976825a2f7948d0fa40907598d69834f8ab5889de11
# Successfully built PyPDF2
# ...

# %%
# !pyppeteer-install
# Out:
# [W:pyppeteer.chromium_downloader] start chromium download.
# Download may take a few minutes.
# 100%|█████████████████████████| 108773488/108773488 [02:38<00:00, 687199.46it/s]
# [W:pyppeteer.chromium_downloader]
# chromium download done.
# [W:pyppeteer.chromium_downloader] chromium extracted to: /root/.local/share/pyppeteer/local-chromium/588429

# %%
# !apt-get install -y pandoc texlive-xetex
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   dbus dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 krb5-locales libapache-pom-java libapparmor1
#   libauthen-sasl-perl libavahi-client3 libavahi-common-data libavahi-common3
#   libbrotli1 libcairo2 libcommons-logging-java libcommons-parent-java libcups2
#   libdata-dump-perl libdbus-1-3 libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libedit2 libelf1
#   libencode-locale-perl libfile-basedir-perl libfile-desktopentry-perl
#   libfile-listing-perl libfile-mimeinfo-perl libfont-afm-perl libfontbox-java
#   libfontenc1 libgl1 libgl1-mesa-dri libglapi-mesa libglib2.0-0
#   libglib2.0-data libglvnd0 libglx-mesa0 libglx0 libgraphite2-3 libgs9
#   libgs9-common libgssapi-krb5-2 libharfbuzz-icu0 libharfbuzz0b
# ...

# %%
# !pip3 install nbconvert
